# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
from modify_acc_var import *
from experiment import titles

for i in range(28):
    if("pseudo_lb_best_policy_overloaded" in titles[0][i] and " 0.99 " in titles[0][i]):
        plt.figure(figsize=(6.4, 9.6))
        a0_90 = dem_90[0][i]
        a0_90 = [x+1 for x in a0_90]
        a1_90 = fpp_90[0][i]
        a1_90 = [x+1 for x in a1_90]
        a0_45 = dem_45[0][i]
        a0_45 = [x+1 for x in a0_45]
        a1_45 = fpp_45[0][i]
        a1_45 = [x+1 for x in a1_45]
        a0_mix = dem_mix[0][i]
        a0_mix = [x+1 for x in a0_mix]
        a1_mix = fpp_mix[0][i]
        a1_mix = [x+1 for x in a1_mix]
        # plt.plot(np.arange(10), a0_90, linestyle='-', marker='o', color='r', label='Positive Prediction Proportion+1 (90)')
        # plt.plot(np.arange(10), a0_45, linestyle='--', marker='o', color='r', label='Positive Prediction Proportion+1 (45)')
        # plt.plot(np.arange(10), a0_mix, linestyle=':', marker='o', color='r', label='Positive Prediction Proportion+1 (mix)')

        # plt.plot(np.arange(10), acc_90[0][i], linestyle='-', marker='o', color='g', label='Accuracy (90)')
        # plt.plot(np.arange(10), acc_45[0][i], linestyle='--', marker='o', color='g', label='Accuracy (45)')
        # plt.plot(np.arange(10), acc_mix[0][i], linestyle=':', marker='o', color='g', label='Accuracy (mix)')

        # plt.plot(np.arange(10), tpp_90[0][i], linestyle='-', marker='o', color='b', label='True Positive Proportion (90)')
        # plt.plot(np.arange(10), tpp_45[0][i], linestyle='--', marker='o', color='b', label='True Positive Proportion (45)')
        # plt.plot(np.arange(10), tpp_mix[0][i], linestyle=':', marker='o', color='b', label='True Positive Proportion (mix)')

        # plt.plot(np.arange(10), a1_90, linestyle='-', marker='o', color='k', label='False Positive Proportion+1 (90)')
        # plt.plot(np.arange(10), a1_45, linestyle='--', marker='o', color='k', label='False Positive Proportion+1 (45)')
        # plt.plot(np.arange(10), a1_mix, linestyle=':', marker='o', color='k', label='False Positive Proportion+1 (mix)')

        plt.plot(np.arange(10), ppv_90[0][i], linestyle='-', marker='o', color='c', label='Positive Prediction Value (90)')
        plt.plot(np.arange(10), ppv_45[0][i], linestyle='--', marker='o', color='c', label='Positive Prediction Value (45)')
        plt.plot(np.arange(10), ppv_mix[0][i], linestyle=':', marker='o', color='c', label='Positive Prediction Value (mix)')
        plt.title(titles[0][i])
        plt.yticks(np.arange(0.4, 1.2, 0.03))
        plt.xticks(np.arange(0, 10, 1))
        plt.xlabel("Class")
        plt.ylabel("Parity Measure")
        plt.legend()
        plt.show()
